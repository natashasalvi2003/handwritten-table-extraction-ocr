# %% [markdown]
# # **FIRST WE BEGIN WITH ALL THE INSTALLATIONS**

# %%
# !pip install openpyxl
# !pip install transformers
# !pip install pandas
# !pip install img2table
# Out:
# Requirement already satisfied: openpyxl in c:\users\natas\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\natas\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: transformers in c:\users\natas\anaconda3\lib\site-packages (4.41.2)
# Requirement already satisfied: filelock in c:\users\natas\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: requests in c:\users\natas\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\natas\anaconda3\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\natas\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\natas\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\natas\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\natas\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\natas\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\natas\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\natas\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\natas\anaconda3\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: pandas in c:\users\natas\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\natas\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natas\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\natas\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\natas\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting img2table
#   Downloading img2table-1.2.11-py3-none-any.whl.metadata (20 kB)
# Collecting polars>=0.20.5 (from polars[pandas]>=0.20.5->img2table)
#   Downloading polars-0.20.31-cp38-abi3-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: pyarrow>=7 in c:\users\natas\anaconda3\lib\site-packages (from img2table) (16.1.0)
# Requirement already satisfied: numpy in c:\users\natas\anaconda3\lib\site-packages (from img2table) (1.21.5)
# Collecting pymupdf>=1.19.1 (from img2table)
#   Downloading PyMuPDF-1.24.5-cp39-none-win_amd64.whl.metadata (3.4 kB)
# Collecting opencv-contrib-python (from img2table)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numba in c:\users\natas\anaconda3\lib\site-packages (from img2table) (0.55.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\natas\anaconda3\lib\site-packages (from img2table) (4.11.1)
# Collecting xlsxwriter>=3.0.6 (from img2table)
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pandas in c:\users\natas\anaconda3\lib\site-packages (from polars[pandas]>=0.20.5->img2table) (1.4.2)
# Collecting PyMuPDFb==1.24.3 (from pymupdf>=1.19.1->img2table)
#   Downloading PyMuPDFb-1.24.3-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\natas\anaconda3\lib\site-packages (from beautifulsoup4->img2table) (2.3.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\natas\anaconda3\lib\site-packages (from numba->img2table) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\natas\anaconda3\lib\site-packages (from numba->img2table) (61.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\natas\anaconda3\lib\site-packages (from pandas->polars[pandas]>=0.20.5->img2table) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natas\anaconda3\lib\site-packages (from pandas->polars[pandas]>=0.20.5->img2table) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\natas\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->polars[pandas]>=0.20.5->img2table) (1.16.0)
# Downloading img2table-1.2.11-py3-none-any.whl (90 kB)
#    ---------------------------------------- 90.2/90.2 kB 1.0 MB/s eta 0:00:00
# Downloading polars-0.20.31-cp38-abi3-win_amd64.whl (28.8 MB)
#    ---------------------------------------- 28.8/28.8 MB 10.9 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.5-cp39-none-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 3.2/3.2 MB 11.3 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.3-py3-none-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 12.4/12.4 MB 11.7 MB/s eta 0:00:00
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ---------------------------------------- 159.9/159.9 kB 9.4 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
#    ---------------------------------------- 45.5/45.5 MB 11.1 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter, PyMuPDFb, polars, opencv-contrib-python, pymupdf, img2table
#   Attempting uninstall: xlsxwriter
#     Found existing installation: XlsxWriter 3.0.3
#     Uninstalling XlsxWriter-3.0.3:
#       Successfully uninstalled XlsxWriter-3.0.3
# Successfully installed PyMuPDFb-1.24.3 img2table-1.2.11 opencv-contrib-python-4.10.0.84 polars-0.20.31 pymupdf-1.24.5 xlsxwriter-3.2.0

# %% [markdown]
# # **NEXT, ALL THE IMPORTS**

# %%
import cv2
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
import requests
import matplotlib.pyplot as plt
import pandas as pd
import openpyxl
from openpyxl import Workbook
from openpyxl.utils import get_column_letter
from PIL import Image as PILImage
from img2table.document import Image as Img2TableImage
import numpy as np

# %% [markdown]
# # **ENTER THE FILEPATH:**

# %%
filepath="C:\\Users\\natas\\Desktop\\IITPL\\ocr\\testimage2.png" #enter image path here

# %% [markdown]
# # **NOW WE WILL VISUALIZE THE TABLE DETECTION**

# %%
img = Img2TableImage(src=filepath)

# Extract tables
extracted_tables = img.extract_tables(implicit_rows=True, borderless_tables=True)

# Display extracted tables
table_img = cv2.imread(filepath)

for table in extracted_tables:
    for row in table.content.values():
        for cell in row:
            cv2.rectangle(table_img, (cell.bbox.x1, cell.bbox.y1), (cell.bbox.x2, cell.bbox.y2), (255, 0, 0), 2)

PILImage.fromarray(table_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1660x830 at 0x14D325AD310>

# %% [markdown]
# # **LASTLY, WE ENTER THESE ENTRIES INTO AN EXCEL SHEET**

# %%
def initialize_trocr_model():
    processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
    model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")
    return processor, model

def extract_tables_from_image(image_path):
    img = Img2TableImage(src=image_path)
    #extracted_tables = img.extract_tables()
    extracted_tables = img.extract_tables(implicit_rows=True, borderless_tables=True)
    return extracted_tables

def recognize_text_in_cell(cell_image, processor, model):
    try:
      # Convert cell_image to PIL image
      pil_image = PILImage.fromarray(cv2.cvtColor(cell_image, cv2.COLOR_BGR2RGB))

      # Prepare the image for the model
      pixel_values = processor(images=pil_image, return_tensors="pt").pixel_values

      # Generate text
      generated_ids = model.generate(pixel_values)
      generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

      return generated_text
    except Exception as e:
      print(f"Error processing image: {e}")
      #err = "unrecognized text"
      err = " "
      return err

def main():
    # Initialize TrOCR model and processor
    processor, model = initialize_trocr_model()

    # Extract tables from the image
    extracted_tables = extract_tables_from_image(filepath)

    # Create an Excel workbook and sheet
    wb = Workbook()
    ws = wb.active

    # Process each table
    for table_idx, table in enumerate(extracted_tables):
        print(f"Table {table_idx + 1}:")
        for id_row, row in enumerate(table.content.values(), start=1):
            for id_col, cell in enumerate(row, start=1):
                x1 = cell.bbox.x1
                y1 = cell.bbox.y1
                x2 = cell.bbox.x2
                y2 = cell.bbox.y2

                # Load the entire table image (optional for display)
                #table_image = cv2.imread(filepath)

                # Crop the cell region from the table image
                cell_image = cv2.imread(filepath)[y1:y2, x1:x2]

                # Display the cell image (optional)
                #plt.imshow(cv2.cvtColor(cell_image, cv2.COLOR_BGR2RGB))
                #plt.axis('off')
                #plt.show()

                # Recognize text in the cell using TrOCR
                recognized_text = recognize_text_in_cell(cell_image, processor, model)
                print(f"Table {table_idx + 1}, Row {id_row}, Column {id_col}: {recognized_text}")

                # Write to Excel sheet
                cell_address = get_column_letter(id_col) + str(id_row)
                ws[cell_address] = recognized_text

                # Adjust column width based on content length
                column_letter = get_column_letter(id_col)
                column_dimensions = ws.column_dimensions[column_letter]
                column_dimensions.width = len(str(recognized_text)) + 12  # Adjusting for padding

    # Save the workbook
    excel_filename = "finaloutput.xlsx"
    wb.save(excel_filename)
    print(f"Excel file saved as '{excel_filename}'.")

if __name__ == "__main__":
    main()
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-handwritten and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Table 1:
# Table 1, Row 1, Column 1: 0 0
# Table 1, Row 1, Column 2: 1123A.655 )
# Table 1, Row 1, Column 3: economic financing.
# Error processing image: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# Table 1, Row 1, Column 4:
# Table 1, Row 1, Column 5: Among
# Table 1, Row 2, Column 1: 0 2.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 81>()
#      79     print(f"Excel file saved as '{excel_filename}'.")
#      81 if __name__ == "__main__":
# ---> 82     main()
#
# Input In [9], in main()
#      56 cell_image = cv2.imread(filepath)[y1:y2, x1:x2]
#      58 # Display the cell image (optional)
#      59 #plt.imshow(cv2.cvtColor(cell_image, cv2.COLOR_BGR2RGB))
#      60 #plt.axis('off')
#      61 #plt.show()
#      62
#      63 # Recognize text in the cell using TrOCR
# ---> 64 recognized_text = recognize_text_in_cell(cell_image, processor, model)
#      65 print(f"Table {table_idx + 1}, Row {id_row}, Column {id_col}: {recognized_text}")
#      67 # Write to Excel sheet
#
# Input In [9], in recognize_text_in_cell(cell_image, processor, model)
#      18 pixel_values = processor(images=pil_image, return_tensors="pt").pixel_values
#      20 # Generate text
# ---> 21 generated_ids = model.generate(pixel_values)
#      22 generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
#      24 return generated_text
#
# File ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\transformers\generation\utils.py:1758, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1750     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1751         input_ids=input_ids,
#    1752         expand_size=generation_config.num_return_sequences,
#    1753         is_encoder_decoder=self.config.is_encoder_decoder,
#    1754         **model_kwargs,
#    1755     )
#    1757     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1758     result = self._sample(
#    1759         input_ids,
#    1760         logits_processor=prepared_logits_processor,
#    1761         logits_warper=prepared_logits_warper,
#    1762         stopping_criteria=prepared_stopping_criteria,
#    1763         generation_config=generation_config,
#    1764         synced_gpus=synced_gpus,
#    1765         streamer=streamer,
#    1766         **model_kwargs,
#    1767     )
#    1769 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1770     # 11. prepare logits warper
#    1771     prepared_logits_warper = (
#    1772         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1773     )
#
# File ~\anaconda3\lib\site-packages\transformers\generation\utils.py:2397, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2394 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2396 # forward pass to get next token
# -> 2397 outputs = self(
#    2398     **model_inputs,
#    2399     return_dict=True,
#    2400     output_attentions=output_attentions,
#    2401     output_hidden_states=output_hidden_states,
#    2402 )
#    2404 if synced_gpus and this_peer_finished:
#    2405     continue  # don't waste resources running the code we don't need
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\vision_encoder_decoder\modeling_vision_encoder_decoder.py:615, in VisionEncoderDecoderModel.forward(self, pixel_values, decoder_input_ids, decoder_attention_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#     610     decoder_input_ids = shift_tokens_right(
#     611         labels, self.config.pad_token_id, self.config.decoder_start_token_id
#     612     )
#     614 # Decode
# --> 615 decoder_outputs = self.decoder(
#     616     input_ids=decoder_input_ids,
#     617     attention_mask=decoder_attention_mask,
#     618     encoder_hidden_states=encoder_hidden_states,
#     619     encoder_attention_mask=encoder_attention_mask,
#     620     inputs_embeds=decoder_inputs_embeds,
#     621     output_attentions=output_attentions,
#     622     output_hidden_states=output_hidden_states,
#     623     use_cache=use_cache,
#     624     past_key_values=past_key_values,
#     625     return_dict=return_dict,
#     626     **kwargs_decoder,
#     627 )
#     629 # Compute loss independent from decoder (as some shift the logits inside them)
#     630 loss = None
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\trocr\modeling_trocr.py:913, in TrOCRForCausalLM.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     910 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     912 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 913 outputs = self.model.decoder(
#     914     input_ids=input_ids,
#     915     attention_mask=attention_mask,
#     916     encoder_hidden_states=encoder_hidden_states,
#     917     encoder_attention_mask=encoder_attention_mask,
#     918     head_mask=head_mask,
#     919     cross_attn_head_mask=cross_attn_head_mask,
#     920     past_key_values=past_key_values,
#     921     inputs_embeds=inputs_embeds,
#     922     use_cache=use_cache,
#     923     output_attentions=output_attentions,
#     924     output_hidden_states=output_hidden_states,
#     925     return_dict=return_dict,
#     926 )
#     928 logits = self.output_projection(outputs[0])
#     930 loss = None
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\trocr\modeling_trocr.py:673, in TrOCRDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     660     layer_outputs = self._gradient_checkpointing_func(
#     661         decoder_layer.__call__,
#     662         hidden_states,
#    (...)
#     670         use_cache,
#     671     )
#     672 else:
# --> 673     layer_outputs = decoder_layer(
#     674         hidden_states,
#     675         attention_mask=attention_mask,
#     676         encoder_hidden_states=encoder_hidden_states,
#     677         encoder_attention_mask=encoder_attention_mask,
#     678         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#     679         cross_attn_layer_head_mask=(
#     680             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#     681         ),
#     682         past_key_value=past_key_value,
#     683         output_attentions=output_attentions,
#     684         use_cache=use_cache,
#     685     )
#     686 hidden_states = layer_outputs[0]
#     688 if use_cache:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\trocr\modeling_trocr.py:380, in TrOCRDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     378 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     379 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 380 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     381     hidden_states=hidden_states,
#     382     key_value_states=encoder_hidden_states,
#     383     attention_mask=encoder_attention_mask,
#     384     layer_head_mask=cross_attn_layer_head_mask,
#     385     past_key_value=cross_attn_past_key_value,
#     386     output_attentions=output_attentions,
#     387 )
#     389 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     390 hidden_states = residual + hidden_states
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\trocr\modeling_trocr.py:203, in TrOCRAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     200     value_states = past_key_value[1]
#     201 elif is_cross_attention:
#     202     # cross_attentions
# --> 203     key_states = self._shape(self.k_proj(key_value_states), -1, bsz)
#     204     value_states = self._shape(self.v_proj(key_value_states), -1, bsz)
#     205 elif past_key_value is not None:
#     206     # reuse k, v, self_attention
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
